# %% [markdown]
# <a href="https://colab.research.google.com/github/gdakate/llm-guided-synthetic-image-pipeline/blob/main/llm_guided_synthetic_image_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("LLM-guided synthetic image pipeline started")
# Out:
# LLM-guided synthetic image pipeline started
